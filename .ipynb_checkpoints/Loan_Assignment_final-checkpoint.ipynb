# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %% [markdown]
# ## Data Extraction

# %%
loans_df = pd.read_csv('loan.csv',encoding='utf-8')
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Data Cleaning

# %%
#Check if there any columns, with all rows null. Remove such columns
loans_df = loans_df.dropna(how='all',axis=1)

# %%
#Check if there are columns with just 1, or 2(null included) unique value, which makes them useless
for col in loans_df.columns:
    unique_vals = loans_df[col].unique()
    num_uniques = len(unique_vals)
    if num_uniques <= 2:
        print (col, unique_vals)
# Out:
# (u'term', array([u' 36 months', u' 60 months'], dtype=object))
# (u'pymnt_plan', array([u'n'], dtype=object))
# (u'initial_list_status', array([u'f'], dtype=object))
# (u'collections_12_mths_ex_med', array([ 0., nan]))
# (u'policy_code', array([1]))
# (u'application_type', array([u'INDIVIDUAL'], dtype=object))
# (u'acc_now_delinq', array([0]))
# (u'chargeoff_within_12_mths', array([ 0., nan]))
# (u'delinq_amnt', array([0]))
# (u'tax_liens', array([ 0., nan]))

# %% [markdown]
# #### Removing the following columns, since they don't contribute to any variance
# pymnt_plan ['n']
# initial_list_status ['f']
# collections_12_mths_ex_med [ 0. nan]
# policy_code [1]
# application_type ['INDIVIDUAL']
# acc_now_delinq [0]
# chargeoff_within_12_mths [ 0. nan]
# delinq_amnt [0]
# tax_liens [ 0. nan]

# %%
loans_df = loans_df.drop(['pymnt_plan','initial_list_status','policy_code','delinq_amnt','acc_now_delinq','application_type','collections_12_mths_ex_med','chargeoff_within_12_mths','tax_liens'], axis=1)

# %% [markdown]
# #### Remove columns that are extremely correlated from each other

# %%
threshold = 0.98
# Create correlation matrix
corr_matrix = loans_df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/computation/check.py:17: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
#print(to_drop)
#print(upper)

# %%
##Redundant columns 'member_id', 'funded_amnt', 'out_prncp_inv' since they are very
##highly correlated with 'id', loan_amnt, out_prncp
loans_df = loans_df.drop(to_drop, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-4c319a4891b5> in <module>()
#       1 ##Redundant columns 'member_id', 'funded_amnt', 'out_prncp_inv' since they are very
#       2 ##highly correlated with 'id', loan_amnt, out_prncp
# ----> 3 loans_df = loans_df.drop(to_drop, axis=1)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    3742             if errors != 'ignore':
#    3743                 raise ValueError('labels %s not contained in axis' %
# -> 3744                                  labels[mask])
#    3745             indexer = indexer[~mask]
#    3746         return self.delete(indexer)
#
# ValueError: labels [u'member_id' u'funded_amnt' u'out_prncp_inv'] not contained in axis

# %%
#Final loan_df shape
print(loans_df.shape)
# Out:
# (39717, 45)

# %%
loans_df.columns
# Out:
# Index([u'id', u'loan_amnt', u'funded_amnt_inv', u'term', u'int_rate',
#        u'installment', u'grade', u'sub_grade', u'emp_title', u'emp_length',
#        u'home_ownership', u'annual_inc', u'verification_status', u'issue_d',
#        u'loan_status', u'url', u'desc', u'purpose', u'title', u'zip_code',
#        u'addr_state', u'dti', u'delinq_2yrs', u'earliest_cr_line',
#        u'inq_last_6mths', u'mths_since_last_delinq', u'mths_since_last_record',
#        u'open_acc', u'pub_rec', u'revol_bal', u'revol_util', u'total_acc',
#        u'out_prncp', u'total_pymnt', u'total_pymnt_inv', u'total_rec_prncp',
#        u'total_rec_int', u'total_rec_late_fee', u'recoveries',
#        u'collection_recovery_fee', u'last_pymnt_d', u'last_pymnt_amnt',
#        u'next_pymnt_d', u'last_credit_pull_d', u'pub_rec_bankruptcies'],
#       dtype='object')

# %%
#Correlation heatmap
sns.set(rc={'figure.figsize':(13.7,10.27)})
sns.heatmap(loans_df.corr(), vmax=1., square=False , cmap="YlGnBu")
plt.show()

# %%
#pair plot 
loans_df['title'].head()
#sns.pairplot(loans_df)
# Out:
# 0                Computer
# 1                    bike
# 2    real estate business
# 3                personel
# 4                Personal
# Name: title, dtype: object

# %%
#wrote filtered columns in a file
#for concenience 
dd= pd.read_csv('dd.csv')
dd[dd['LoanStatNew'].isin(loans_df.columns)].to_csv('fdd.csv', sep=',')

# %% [markdown]
# ### Bivariate Analysis

# %%
##Let's check if zip code affects loan default

# %%
zipcode_pivot_df =loans_df.pivot_table(index='zip_code',columns='loan_status', values='id',aggfunc='count',fill_value=0)

# %%
zipcode_pivot_df['default_ratio_loanscompleted%'] = (zipcode_pivot_df['Charged Off']/(zipcode_pivot_df['Fully Paid']+ zipcode_pivot_df['Charged Off']))*100

# %%
zipcode_pivot_df.sort_values(by='default_ratio_loanscompleted%', inplace=True, ascending=False)

# %%
zipcode_pivot_df['total_loans_completed'] =zipcode_pivot_df['Fully Paid']+ zipcode_pivot_df['Charged Off']

# %%
zipcode_pivot_df.loc[(zipcode_pivot_df['default_ratio_loanscompleted%'] > 70) & (zipcode_pivot_df.total_loans_completed>5)]
# Out:
# loan_status  Charged Off  Current  Fully Paid  default_ratio_loanscompleted%  \
# zip_code
# 561xx                  5        0           2                      71.428571
# 746xx                  5        0           2                      71.428571
#
# loan_status  total_loans_completed
# zip_code
# 561xx                            7
# 746xx                            7

# %%
#TODO 
#1 ) Linear Discriminate Analysis
#
